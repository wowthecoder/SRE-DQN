# %% [markdown]
# # Pommerman FFA Deep SRQ PATH TVC Pool Evaluation
#
# Evaluate full four-agent Deep SRQ checkpoints trained with the `path_tvc_mcp_nplayer_pool` stage solver.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
for parent in (ROOT, *ROOT.parents):
    if (parent / "discrete_action_space").exists() and (parent / "relevant_papers").exists():
        ROOT = parent
        break

for path in (ROOT, ROOT / "discrete_action_space", ROOT / "discrete_action_space" / "bimatrix_game"):
    if str(path) not in sys.path:
        sys.path.insert(0, str(path))

from discrete_action_space.pommerman_ffa.notebook_utils import (
    configure_notebook_imports,
    evaluate_pommerman_deepsrq_path_tvc_pool_for_epsilon,
)

ROOT = configure_notebook_imports(ROOT)
EVAL_EPISODES = 20
MAX_STEPS = 200
USE_GPU = True
CHECKPOINT_NAME = "best"
POOL_SIZE = 16

# %% [markdown]
# ## epsilon = 0.01

# %%
eval_eps_001 = evaluate_pommerman_deepsrq_path_tvc_pool_for_epsilon(
    0.01,
    n_episodes=EVAL_EPISODES,
    max_steps=MAX_STEPS,
    repo_root=ROOT,
    use_gpu=USE_GPU,
    checkpoint_name=CHECKPOINT_NAME,
    sre_solver_workers=POOL_SIZE,
)
# Out:
# pommerman:evaluate:deep_srq_path_tvc_pool_eps_0.01:   0%|                                        | 0/20 [00:00<?, ?it/s]/home/wowthecoder/SRE-DQN/venv/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:225: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
# pommerman:evaluate:deep_srq_path_tvc_pool_eps_0.01: 100%|███████████████████████████████| 20/20 [00:40<00:00,  2.01s/it]

# %% [markdown]
# ## epsilon = 0.1

# %%
eval_eps_01 = evaluate_pommerman_deepsrq_path_tvc_pool_for_epsilon(
    0.1,
    n_episodes=EVAL_EPISODES,
    max_steps=MAX_STEPS,
    repo_root=ROOT,
    use_gpu=USE_GPU,
    checkpoint_name=CHECKPOINT_NAME,
    sre_solver_workers=POOL_SIZE,
)
# Out:
# pommerman:evaluate:deep_srq_path_tvc_pool_eps_0.1:   0%|                                         | 0/20 [00:00<?, ?it/s]/home/wowthecoder/SRE-DQN/venv/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:225: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
# pommerman:evaluate:deep_srq_path_tvc_pool_eps_0.1: 100%|████████████████████████████████| 20/20 [00:29<00:00,  1.48s/it]

# %% [markdown]
# ## epsilon = 0.5

# %%
eval_eps_05 = evaluate_pommerman_deepsrq_path_tvc_pool_for_epsilon(
    0.5,
    n_episodes=EVAL_EPISODES,
    max_steps=MAX_STEPS,
    repo_root=ROOT,
    use_gpu=USE_GPU,
    checkpoint_name=CHECKPOINT_NAME,
    sre_solver_workers=POOL_SIZE,
)
# Out:
# pommerman:evaluate:deep_srq_path_tvc_pool_eps_0.5:   0%|                                         | 0/20 [00:00<?, ?it/s]/home/wowthecoder/SRE-DQN/venv/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:225: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
# pommerman:evaluate:deep_srq_path_tvc_pool_eps_0.5: 100%|████████████████████████████████| 20/20 [00:36<00:00,  1.81s/it]

# %% [markdown]
# ## epsilon = 1.0

# %%
eval_eps_10 = evaluate_pommerman_deepsrq_path_tvc_pool_for_epsilon(
    1.0,
    n_episodes=EVAL_EPISODES,
    max_steps=MAX_STEPS,
    repo_root=ROOT,
    use_gpu=USE_GPU,
    checkpoint_name=CHECKPOINT_NAME,
    sre_solver_workers=POOL_SIZE,
)
# Out:
# pommerman:evaluate:deep_srq_path_tvc_pool_eps_1.0:   0%|                                         | 0/20 [00:00<?, ?it/s]/home/wowthecoder/SRE-DQN/venv/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:225: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
# pommerman:evaluate:deep_srq_path_tvc_pool_eps_1.0: 100%|████████████████████████████████| 20/20 [00:38<00:00,  1.95s/it]
