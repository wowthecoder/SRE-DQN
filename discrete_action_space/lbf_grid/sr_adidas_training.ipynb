# %% [markdown]
# # SR-ADIDAS Training
#
# Training-only notebook for SR-ADIDAS on the same LBF scenarios and robust epsilon sweep. Each epsilon cell saves best/final full-resume checkpoints plus reward plots.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if ROOT.name == "lbf_grid":
    REPO_ROOT = ROOT.parents[1]
elif (ROOT / "discrete_action_space" / "lbf_grid").exists():
    REPO_ROOT = ROOT
else:
    REPO_ROOT = ROOT.parents[1]

for path in [REPO_ROOT, REPO_ROOT / "discrete_action_space", REPO_ROOT / "discrete_action_space" / "lbf_grid"]:
    if str(path) not in sys.path:
        sys.path.insert(0, str(path))

from discrete_action_space.lbf_grid.robust_notebook_utils import (
    DEFAULT_EVAL_EPISODES,
    DEFAULT_NFG_TRANSFORMER_CHECKPOINT,
    ROBUST_EPSILONS,
    evaluate_deepsrq_suite_for_epsilon,
    evaluate_sr_adidas_suite_for_epsilon,
    robust_lbf_scenarios,
    train_deepsrq_nfgtransformer_for_epsilon,
    train_sr_adidas_for_epsilon,
)

SCENARIOS = robust_lbf_scenarios()
for scenario in SCENARIOS:
    print(f"{scenario.key}: {scenario.name}")
NUM_ENVS = 8
EVAL_NUM_ENVS = NUM_ENVS

# %%
N_EPISODES = 3000
USE_GPU = True
BASE_SEED = 2025
EVAL_INTERVAL = 100
EVAL_EPISODES_DURING_TRAINING = 10

print(f"Robust epsilons: {ROBUST_EPSILONS}")
# Out:
# Robust epsilons: (0.01, 0.1, 0.5, 1.0)

# %% [markdown]
# ## Robust epsilon 0.01

# %%
sr_adidas_eps_0_01_stats = train_sr_adidas_for_epsilon(
    0.01,
    n_episodes=N_EPISODES,
    scenarios=SCENARIOS,
    base_seed=BASE_SEED + 1,
    use_gpu=USE_GPU,
    eval_interval=EVAL_INTERVAL,
    eval_episodes=EVAL_EPISODES_DURING_TRAINING,
    repo_root=REPO_ROOT,
    num_envs=NUM_ENVS,
    eval_num_envs=EVAL_NUM_ENVS,
)
sr_adidas_eps_0_01_stats

# %% [markdown]
# ## Robust epsilon 0.1

# %%
sr_adidas_eps_0_1_stats = train_sr_adidas_for_epsilon(
    0.1,
    n_episodes=N_EPISODES,
    scenarios=SCENARIOS,
    base_seed=BASE_SEED + 10,
    use_gpu=USE_GPU,
    eval_interval=EVAL_INTERVAL,
    eval_episodes=EVAL_EPISODES_DURING_TRAINING,
    repo_root=REPO_ROOT,
    num_envs=NUM_ENVS,
    eval_num_envs=EVAL_NUM_ENVS,
)
sr_adidas_eps_0_1_stats

# %% [markdown]
# ## Robust epsilon 0.5

# %%
sr_adidas_eps_0_5_stats = train_sr_adidas_for_epsilon(
    0.5,
    n_episodes=N_EPISODES,
    scenarios=SCENARIOS,
    base_seed=BASE_SEED + 50,
    use_gpu=USE_GPU,
    eval_interval=EVAL_INTERVAL,
    eval_episodes=EVAL_EPISODES_DURING_TRAINING,
    repo_root=REPO_ROOT,
    num_envs=NUM_ENVS,
    eval_num_envs=EVAL_NUM_ENVS,
)
sr_adidas_eps_0_5_stats

# %% [markdown]
# ## Robust epsilon 1.0

# %%
sr_adidas_eps_1_0_stats = train_sr_adidas_for_epsilon(
    1.0,
    n_episodes=N_EPISODES,
    scenarios=SCENARIOS,
    base_seed=BASE_SEED + 100,
    use_gpu=USE_GPU,
    eval_interval=EVAL_INTERVAL,
    eval_episodes=EVAL_EPISODES_DURING_TRAINING,
    repo_root=REPO_ROOT,
    num_envs=NUM_ENVS,
    eval_num_envs=EVAL_NUM_ENVS,
)
sr_adidas_eps_1_0_stats
