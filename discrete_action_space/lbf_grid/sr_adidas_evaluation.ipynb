# %% [markdown]
# # SR-ADIDAS Evaluation
#
# Loads the best SR-ADIDAS checkpoints, runs self-play evaluation, and evaluates rotated focal-slot matchups against random, IQL, MAPPO, QMIX, and Deep SRQ NfgTransformer.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if ROOT.name == "lbf_grid":
    REPO_ROOT = ROOT.parents[1]
elif (ROOT / "discrete_action_space" / "lbf_grid").exists():
    REPO_ROOT = ROOT
else:
    REPO_ROOT = ROOT.parents[1]

for path in [REPO_ROOT, REPO_ROOT / "discrete_action_space", REPO_ROOT / "discrete_action_space" / "lbf_grid"]:
    if str(path) not in sys.path:
        sys.path.insert(0, str(path))

from discrete_action_space.lbf_grid.robust_notebook_utils import (
    DEFAULT_EVAL_EPISODES,
    DEFAULT_NFG_TRANSFORMER_CHECKPOINT,
    ROBUST_EPSILONS,
    evaluate_deepsrq_suite_for_epsilon,
    evaluate_sr_adidas_suite_for_epsilon,
    robust_lbf_scenarios,
    train_deepsrq_nfgtransformer_for_epsilon,
    train_sr_adidas_for_epsilon,
)

SCENARIOS = robust_lbf_scenarios()
for scenario in SCENARIOS:
    print(f"{scenario.key}: {scenario.name}")

# %%
EVAL_EPISODES = DEFAULT_EVAL_EPISODES
USE_GPU = True
print(f"Evaluation episodes per matchup: {EVAL_EPISODES}")
print(f"Robust epsilons: {ROBUST_EPSILONS}")

# %% [markdown]
# ## Robust epsilon 0.01

# %%
sr_adidas_eval_eps_0_01 = evaluate_sr_adidas_suite_for_epsilon(
    0.01,
    scenarios=SCENARIOS,
    n_episodes=EVAL_EPISODES,
    repo_root=REPO_ROOT,
    use_gpu=USE_GPU,
)
sr_adidas_eval_eps_0_01

# %% [markdown]
# ## Robust epsilon 0.1

# %%
sr_adidas_eval_eps_0_1 = evaluate_sr_adidas_suite_for_epsilon(
    0.1,
    scenarios=SCENARIOS,
    n_episodes=EVAL_EPISODES,
    repo_root=REPO_ROOT,
    use_gpu=USE_GPU,
)
sr_adidas_eval_eps_0_1

# %% [markdown]
# ## Robust epsilon 0.5

# %%
sr_adidas_eval_eps_0_5 = evaluate_sr_adidas_suite_for_epsilon(
    0.5,
    scenarios=SCENARIOS,
    n_episodes=EVAL_EPISODES,
    repo_root=REPO_ROOT,
    use_gpu=USE_GPU,
)
sr_adidas_eval_eps_0_5

# %% [markdown]
# ## Robust epsilon 1.0

# %%
sr_adidas_eval_eps_1_0 = evaluate_sr_adidas_suite_for_epsilon(
    1.0,
    scenarios=SCENARIOS,
    n_episodes=EVAL_EPISODES,
    repo_root=REPO_ROOT,
    use_gpu=USE_GPU,
)
sr_adidas_eval_eps_1_0
